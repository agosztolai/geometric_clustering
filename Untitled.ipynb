# %%
import numpy as np
import scipy as sc
import time as time
#from scipy.sparse import csr_matrix
from scipy.sparse.csgraph import connected_components as conncomp
#from funs import ORcurvAll_sparse_full, distGeo, diffDist, plotCluster, inputGraphs
from funs import *
#import networkx as nx
import pylab as plt 

from params import *

# load graph ##WARNING currently only works for directed
try:
    G
except NameError:
    (G,Aold,L,pos) = inputGraphs(whichGraph) 
     
# geodesic distances (this is OK for directed)
dist = np.array(distGeo(Aold))


Kappa = ORcurvAll_sparse_parallel(G, dist, T, cutoff, lamb)
# Out:
# 100%|██████████| 18/18 [00:01<00:00,  9.95it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]/home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_util.py:704: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning)
# /home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_util.py:704: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning)
# /home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_util.py:704: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning)
# /home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_util.py:704: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning)
# /home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_ip.py:273: OptimizeWarning: Solving system with option 'sym_pos':True failed. It is normal for this to happen occasionally, especially as the solution is approached. However, if you see this frequently, consider setting option 'sym_pos' to False.
#   OptimizeWarning)
# /home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_ip.py:285: OptimizeWarning: Solving system with option 'sym_pos':False failed. This may happen occasionally, especially as the solution is approached. However, if you see this frequently, your problem may be numerically challenging. If you cannot improve the formulation, consider setting 'lstsq' to True. Consider also setting `presolve` to True, if it is not already.
#   OptimizeWarning)
# /home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_util.py:704: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning)
#  20%|██        | 5/25 [00:09<02:02,  6.14s/it]/home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_ip.py:273: OptimizeWarning: Solving system with option 'sym_pos':True failed. It is normal for this to happen occasionally, especially as the solution is approached. However, if you see this frequently, consider setting option 'sym_pos' to False.
#   OptimizeWarning)
# /home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_ip.py:285: OptimizeWarning: Solving system with option 'sym_pos':False failed. This may happen occasionally, especially as the solution is approached. However, if you see this frequently, your problem may be numerically challenging. If you cannot improve the formulation, consider setting 'lstsq' to True. Consider also setting `presolve` to True, if it is not already.
#   OptimizeWarning)
#  44%|████▍     | 11/25 [00:24<00:38,  2.76s/it]/home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_ip.py:273: OptimizeWarning: Solving system with option 'sym_pos':True failed. It is normal for this to happen occasionally, especially as the solution is approached. However, if you see this frequently, consider setting option 'sym_pos' to False.
#   OptimizeWarning)
# /home/arnaudon/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_ip.py:285: OptimizeWarning: Solving system with option 'sym_pos':False failed. This may happen occasionally, especially as the solution is approached. However, if you see this frequently, your problem may be numerically challenging. If you cannot improve the formulation, consider setting 'lstsq' to True. Consider also setting `presolve` to True, if it is not already.
#   OptimizeWarning)
# 100%|██████████| 25/25 [00:41<00:00,  1.96s/it]

# %%
#import pylab as plt
import MarkovStability as ms

#%matplotlib notebook
nComms = np.zeros([sample, len(T)]) 
nComms_louv = np.zeros(len(T)) 

vi = np.zeros(len(T))
#G_orig = G.copy()
#G = nx.complete_graph(len(G), create_using=G)
for i,j in G.edges:
    G[i][j]['weight'] = 1
w_s = []   
pos = nx.spring_layout(G)

for i in range(len((T))):
    #print(' Diffusion time: ', t)

    #A = Aold.copy()
    # update edge curvatures
    for e, edge in enumerate(G.edges):
        #G.edges[edge]['kappa'] =(Kappa[e][i])
        G.edges[edge]['weight'] =(Kappa[e][i])

    #cluster (remove edges with negative curv and find conn comps)   

    #Kappa_tmp = np.array(nx.to_numpy_matrix(G, weight='kappa')) 

    #cluster (remove edges with negative curv and find conn comps)   
    #mink = np.min(Kappa_tmp)
    #maxk = np.max(Kappa_tmp)
    #labels = np.zeros([A.shape[0],sample])
    #thres = np.random.normal(0, perturb*(maxk-mink), sample)

    #for k in range(sample):
    #    ind = np.where(Kappa_tmp<=thres[k])     
    #    A = Aold.copy()
    #    A[ind[0],ind[1]] = 0 #remove edges with -ve curv.       
    #    (nComms[k,i], labels[:,k]) = conncomp(csr_matrix(A, dtype=int), directed=False, return_labels=True)
        
    louvain_runs = 10
    precision = 1e-5
    stab_linear = ms.Stability(G,'modularity_signed', louvain_runs , precision, True)
    stab_linear.all_mi = False
    stab_linear.n_mi = 5 
    stab_linear.n_processes_louv = 1
    stab_linear.n_processes_mi = 1
    stab_linear.post_process = True
    stab_linear.n_neigh = 10

    stab_linear.run_single_stability(1.)
    stab_linear.print_single_result(1,1)
    
    
    nComms_louv[i] = stab_linear.single_stability_result['number_of_comms']
    labels[:,0] = stab_linear.single_stability_result['community_id']

    
    #A_s = nx.adjacency_matrix(G, weight='kappa').toarray()
    #D = np.diag(abs(A_s).sum(1))
    #L = D - A_s
    #w, v = np.linalg.eigh(L)
    #v = v[:,np.argsort(w)]
    #w = w[np.argsort(w)]
    #w_s.append(np.min(w))
    #print(i, np.min(w))
    #plt.figure()
    #plt.plot(w,'+')

    #pos  = {}
    #for i_n in G:
    #    pos[i_n] = [-v[i_n,0], -v[i_n,1]]
    
    # compute VI
    #(vi[i],_) = varinfo(labels);
    vi[i]  = stab_linear.single_stability_result['MI']
    #plotCluster(G,T,pos,i,labels[:,0],vi[0:i+1],np.mean(nComms[:,0:i+1],axis=0))
    plotCluster(G,T,pos,i,labels[:,0],vi[0:i+1],nComms_louv[0:i+1])

    plt.close()
# Out:
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.318
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.32
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.322
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.324
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.326
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.328
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.33
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.332
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.334
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.336
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.338
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.341
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.343
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.346
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.348
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.351
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.353
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.356
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.359
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.362
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.365
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.368
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.371
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.375
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.378
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.382
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.386
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.39
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.394
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.399
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.403
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.408
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.413
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.418
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.424
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.429
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.435
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.441
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.448
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.455
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.462
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.469
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.477
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.486
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.494
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.503
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.512
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.522
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.533
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.543
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.555
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.566
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.579
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.591
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.605
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.619
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.633
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.648
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.664
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.681
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.698
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.715
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.733
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.752
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.772
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  1.781
# Step  1 / 1
# T      =  1.0
# N_comm =  4
# MI     =  1.0
# Q      =  1.792
# Step  1 / 1
# T      =  1.0
# N_comm =  4
# MI     =  1.0
# Q      =  1.806
# Step  1 / 1
# T      =  1.0
# N_comm =  4
# MI     =  1.0
# Q      =  1.819
# Step  1 / 1
# T      =  1.0
# N_comm =  4
# MI     =  1.0
# Q      =  1.833
# Step  1 / 1
# T      =  1.0
# N_comm =  4
# MI     =  1.0
# Q      =  1.846
# Step  1 / 1
# T      =  1.0
# N_comm =  4
# MI     =  1.0
# Q      =  1.859
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.861
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.863
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.865
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.867
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.869
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.872
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.874
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.876
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.878
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.881
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.883
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.885
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.888
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.89
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.892
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.895
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.897
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.9
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.902
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.905
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.907
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.91
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.913
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.916
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.918
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.921
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.924
# Step  1 / 1
# T      =  1.0
# N_comm =  2
# MI     =  1.0
# Q      =  1.927

# %%
G, Aold, L, pos = inputGraphs(whichGraph) 


louvain_runs = 10
precision = 1e-5
stab_linear = ms.Stability(G,'continuous_normalized', louvain_runs , precision, True)
stab_linear.all_mi = False
stab_linear.n_mi = 5
stab_linear.n_processes_louv = 1
stab_linear.n_processes_mi = 1
stab_linear.post_process = False
stab_linear.n_neigh = 20

stab_linear.run_single_stability(1.)
stab_linear.print_single_result(1,1)
# Out:
# Step  1 / 1
# T      =  1.0
# N_comm =  6
# MI     =  1.0
# Q      =  0.621

# %%
times = np.logspace(-1., 1., 100)
stab_linear.scan_stability(times, disp=False)
# Out:
# 100%|██████████| 100/100 [00:37<00:00,  2.67it/s]

# %%
# %matplotlib notebook
stab_linear.plot_scan(time_axis=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9166666666667">
# /home/arnaudon/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2966: UserWarning: Attempted to set non-positive xlimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive xlimits for log-scale axis; '
