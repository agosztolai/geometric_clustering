# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
import os
import yaml
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import geocluster as gc
from geocluster import plotting
import networkx as nx
from graph_library import assign_graph_metadata
import scipy as sc
import matplotlib.gridspec as gridspec

n = 30
graph = nx.stochastic_block_model([n, n, n, n], [[0.8, 0.02, 0.1, 0.02],
                                                 [0.02, 0.8, 0.02, 0.1],
                                                 [0.1, 0.02, 0.8, 0.02],
                                                 [0.02, 0.1, 0.02, 0.8]], seed=1)

graph_name = 'multiscale'

def random_disk(circle_x=0, circle_y=0, circle_r=1):
    # random angle
    alpha = 2 * np.pi * np.random.uniform()
    # random radius
    r = circle_r * np.sqrt(np.random.uniform())
    # calculating coordinates
    x = r * np.cos(alpha) + circle_x
    y = r * np.sin(alpha) + circle_y
    return np.array([x,y])

pos = {}
for i in graph.nodes:
    if i<n:
        pos[i] = random_disk(0,3)
    elif i<2*n:
        pos[i] = random_disk(3,3)
    elif i<3*n:
        pos[i] = random_disk(0,0)
    elif i<4*n:
        pos[i] = random_disk(3,0)
        
graph = nx.convert_node_labels_to_integers(graph)
graph = assign_graph_metadata(graph, pos=pos)
#nx.draw(graph, pos)
graph = nx.convert_node_labels_to_integers(graph)

if not os.path.isdir(graph_name):
    os.mkdir(graph_name)

params = yaml.full_load(open("params.yaml", "rb"))

# %%
t_min = -3
t_max = 1
n_t = 100
times = np.logspace(t_min, t_max, n_t)

# Compute the OR curvatures
kappas = gc.compute_curvatures(graph, times, params)
# Out:
# ...
# 100%|██████████| 100/100 [01:02<00:00,  1.60it/s]

# %%
# compute all neighbourhood densities
def mx_comp(L, T, cutoff, i):
    N = np.shape(L)[0]

    def delta(i, n):
        p0 = np.zeros(n)
        p0[i] = 1.
        return p0

    mx_all, Nx_all = [], [] 
    mx_tmp = delta(i, N) #set initial condition
    T = [0,] + list(T) #add time 0
    
    for i in range(len((T))-1): 
        #compute exponential by increments (faster than from 0)
        mx_tmp = sc.sparse.linalg.expm_multiply(-(T[i+1]-T[i])*L, mx_tmp)

        Nx = np.argwhere(mx_tmp >= (1-cutoff)*np.max(mx_tmp))
        mx_all.append(sc.sparse.lil_matrix(mx_tmp[Nx]/np.sum(mx_tmp[Nx])))
        Nx_all.append(Nx)

    return mx_all, Nx_all


# compute curvature for an edge ij
def zeta_comp(mx_all, dist, it, e):
    import ot
    
    i, j = e[0], e[1]
    nt = len(mx_all[0][0])
    K = np.zeros(nt)

    Nx = np.array(mx_all[i][1][it]).flatten()
    Ny = np.array(mx_all[j][1][it]).flatten()
    mx = mx_all[i][0][it].toarray().flatten()
    my = mx_all[j][0][it].toarray().flatten()

    dNxNy = dist[Nx,:][:,Ny].copy(order='C')
    zeta = ot.emd(mx, my, dNxNy) 
            
    return zeta

# plot the curvature on the graph for a given time t
def plot_measure_graph(mx1, mx2, kappa, graph, pos, node_size = 100, edge_width = .5, ax=None):

    edge_vmin = -np.max(abs(kappa))
    edge_vmax = np.max(abs(kappa))
              
    vmin = 0# -np.max(abs(mx))
    vmax = 1#np.max(abs(mx))
    mx1 /= np.max(mx1)
    mx2 /= np.max(mx2)

    node_size1, node_size2 = mx1*node_size, mx2*node_size 

    from matplotlib.markers import MarkerStyle
    ms1 = MarkerStyle('o', fillstyle = 'left')
    ms2 = MarkerStyle('o', fillstyle = 'right')
    node_color1 = 'C0'
    node_color2 = 'C1'

    nodes = nx.draw_networkx_nodes(graph, pos = pos, node_size = node_size1, node_color = node_color1, 
                                   vmin = vmin, vmax = vmax, cmap=plt.get_cmap('viridis'),node_shape=ms1,
                                   ax=ax)
    
    nodes = nx.draw_networkx_nodes(graph, pos = pos, node_size = node_size2, node_color = node_color2, 
                                   vmin = vmin, vmax = vmax, cmap=plt.get_cmap('viridis'),node_shape=ms2,
                                   ax=ax)
    
    edges = nx.draw_networkx_edges(graph, pos = pos, width = edge_width, ax=ax,alpha=0.2)

    limits = plt.axis('off') #turn axis off
    
    return ax

# %%
import ot

t = 45

i = 6
j = 16

mx_all = []
for k in range(nx.number_of_nodes(graph)):
    mx_all.append(mx_comp(laplacian, times, 1, k))

Nx = np.array(mx_all[i][1][t]).flatten()
Ny = np.array(mx_all[j][1][t]).flatten()
mx = mx_all[i][0][t].toarray().flatten()
my = mx_all[j][0][t].toarray().flatten()

dNxNy = dist[Nx,:][:,Ny].copy(order='C')
zeta = ot.emd(mx, my, dNxNy)

# %%
plotting.plot_edge_curvatures(times, kappas, figsize=(4,3))
plt.xlabel('time')
plt.ylabel(r'$\kappa$')
peak_position = 48
plt.axvline(times[peak_position])
peak_position = 58
plt.axvline(times[peak_position])
plt.savefig('./multiscale/curvature_trajectories.svg')

# %%
from geocluster.curvature import *
laplacian = construct_laplacian(graph, params["use_spectral_gap"])
geodesic_distances = compute_distance_geodesic(graph)

plt.figure(figsize=(4,3.5))
plt.imshow(geodesic_distances,aspect='auto', origin='auto',cmap='Greys')

plt.xlabel('Node id')
plt.ylabel('Node id')
plt.colorbar(label=r'$d_{ij}$')
plt.axis('square')

#plt.savefig('./multiscale/geodesic.svg')
# Out:
# (-0.5, 119.5, -0.5, 119.5)

# %%
import multiprocessing
times_with_zero = np.hstack([0.0, times])  # add 0 timepoint

measures = list(np.eye(len(graph)))
pool = multiprocessing.Pool(params["n_workers"])
measures_all = []
for time_index in tqdm(range(len(times))):
    worker_measure = WorkerMeasures(
    laplacian, times_with_zero[time_index + 1] - times_with_zero[time_index]
    )
    measures = pool.map(
        worker_measure,
        measures,
    )
    measures_all += [measures]
# Out:
# 100%|██████████| 100/100 [00:05<00:00, 18.54it/s]

# %%
i = 1
j = 65
peak_position=50
mx1 = measures_all[peak_position][i]
mx2 = measures_all[peak_position][j]

fig = plt.figure(figsize=(4,3))
pos = list(nx.get_node_attributes(graph, "pos").values()) 
plot_measure_graph(mx1, mx2, kappas, graph, pos, node_size = 500, edge_width = 1)
nx.draw_networkx_edges(graph, pos = pos, edgelist=[(i,j),], edge_color='g',width = 10)

plt.savefig('./multiscale/measures.svg', bbox_inches='tight')

# %%
i = 1
j = 2

peak_position=48
mx1 = measures_all[peak_position][i]
mx2 = measures_all[peak_position][j]

fig = plt.figure(figsize=(4,3))
pos = list(nx.get_node_attributes(graph, "pos").values()) 

plot_measure_graph(mx1, mx2, kappas, graph, pos, node_size = 500, edge_width = 1)

nx.draw_networkx_edges(graph, pos = pos, edgelist=[(i,j),], edge_color='g',width = 10)

plt.savefig('./multiscale/measures_in.svg', bbox_inches='tight')

# %%
def edge_curvature(measures, geodesic_distances, edge): 
    """compute curvature for an edge ij"""
    # get the edge/nodes ids                                                                                           
    i = edge[0]                                                                                                        
    j = edge[1]
            
    # get the measures
    m_x = measures[i]
    m_y = measures[j]
        
    # set reduce the sized with cutoffs                                                                                
    Nx = np.where(m_x >= (1.0 - params["cutoff"]) * np.max(m_x))[0]
    Ny = np.where(m_y >= (1.0 - params["cutoff"]) * np.max(m_y))[0]
                                                                                                                       
    distances_xy = geodesic_distances[np.ix_(Nx, Ny)]                                                                  

    m_x = m_x[Nx]                                                                                                      
    m_y = m_y[Ny]
    
    m_x /= m_x.sum()
    m_y /= m_y.sum()                                                                                                   
    
    return ot.emd(m_x, m_y, distances_xy)                                                         

zeta = edge_curvature(measures_all[peak_position], geodesic_distances, (i, j))

# %%
def plot_transport_plan(zeta, mx1, mx2):       
    gs = gridspec.GridSpec(2, 2, height_ratios = [ 0.2, 1], width_ratios = [1,0.2] )
    gs.update(wspace=0.00)
    gs.update(hspace=0)
    ax1 = plt.subplot(gs[1, 0])
    ax2 = plt.subplot(gs[0, 0])
    ax3 = plt.subplot(gs[1, 1])
    
    ax1.imshow(zeta.T, cmap='viridis', aspect='auto', origin='auto')
    ax1.set_xlabel('Node id')
    ax1.set_ylabel('Node id')
  
    ax2.bar(np.arange(len(mx1)), mx1,color='C0',log=False)
    ax2.set_xlim(-0.5,len(mx1)-0.5)
    ax2.tick_params(
        axis='x',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        labelbottom=False)
    ax2.set_ylabel('$p_x$')
    
    ax3.barh(np.arange(len(mx2)),mx2,color='C1',log=False)
    ax3.set_ylim(-0.5,len(mx2)-0.5)
    ax3.set_xlabel('$p_y$')
    ax3.tick_params(
        axis='y',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        left=False,      # ticks along the bottom edge are off
        top=False,         # ticks along the top edge are off
        labelleft=False)


    ax1.axvline(20,c='k',ls='--',lw=0.8)
    ax1.axvline(40.,c='k',ls='--',lw=0.8)
    ax1.axvline(60,c='k',ls='--',lw=0.8)
    ax1.axhline(20,c='k',ls='--',lw=0.8)
    ax1.axhline(40.,c='k',ls='--',lw=0.8)
    ax1.axhline(60,c='k',ls='--',lw=0.8)

# %%
from matplotlib import gridspec
fig= plt.figure(figsize=(4, 4))

plot_transport_plan(np.log10(zeta), mx1, mx2)

#plt.savefig('transportation_plan.svg', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="287.77778540128566">
# /home/gosztolai/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f416107bbd0>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f41610eb090>)
# <img src="data:image/png;base64,..." width="287.77778540128566">

# %%
cluster_results = gc.cluster(graph, times, kappas, params, global_time=4)

# %%
from pygenstability.plotting import plot_scan, plot_single_community
def plot_scan_plt(all_results, time_axis=True, figure_name="scan_results.svg"):
    """Plot results of pygenstability with matplotlib."""
    gs = gridspec.GridSpec(2, 1, height_ratios=[1.0, 0.5])
    gs.update(hspace=0)

    if "ttprime" in all_results:
        ax0 = plt.subplot(gs[0, 0])
        plot_ttprime(all_results, ax=ax0)
        ax1 = ax0.twinx()
    else:
        ax1 = plt.subplot(gs[0, 0])

    ax1.set_xticks([])

    plot_number_comm(all_results, ax=ax1, time_axis=time_axis)

    if "ttprime" in all_results:
        ax1.yaxis.tick_right()
        ax1.yaxis.set_label_position("right")

    ax2 = plt.subplot(gs[1, 0])

    if "stability" in all_results:
        plot_stability(all_results, ax=ax2, time_axis=time_axis)

    if "mutual_information" in all_results:
        ax3 = ax2.twinx()
        plot_mutual_information(all_results, ax=ax3, time_axis=time_axis)

    plt.savefig(figure_name, bbox_inches="tight")
plt.figure(figsize=(4,4))
plot_scan(
    cluster_results, figure_name="clustering_scan.svg", use_plotly=False
)

# %%
times = [16, 30]
edge_color="0.5"
edge_width = 2
pos = [graph.nodes[u]["pos"] for u in graph]
for time_id in times:
    plt.figure(figsize=(4,3))
    plot_single_community(
        graph, cluster_results, time_id, edge_color="1", edge_width=0, node_size=50
    )
    plotting.plot_graph(
        graph, edge_color=kappas[time_id], node_size=0, edge_width=edge_width, vmin=-0.15, vmax=.15
    )
    plt.savefig('cluster_' + str(time_id) + '.svg')

# %%
plt.figure(figsize=(8,4))
plt.subplot(121)

kappa = kappas[48]
plotting.plot_graph(
    graph,
    edge_color=kappa,
    node_size=20,
    edge_width=1,
    node_colors='k',
    colormap="standard",
    vmin=-.5,
    vmax=0.5,
)

plt.subplot(122)

kappa = kappas[58]
plotting.plot_graph(
    graph,
    edge_color=kappa,
    node_size=20,
    edge_width=1,
    node_colors='k',
    colormap="standard",
    vmin=-.5,
    vmax=0.5,
)

plt.savefig('./multiscale/curvature_on_graph.svg')
