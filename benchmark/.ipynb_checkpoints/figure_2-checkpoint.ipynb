# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import sys as sys
import os as os
from geocluster import GeoCluster
from graph_library import generate_barbell, generate_tree, generate_clique_of_cliques, assign_graph_metadata
import networkx as nx
import scipy as sc
import pylab as plt
import matplotlib.gridspec as gridspec
from matplotlib.animation import FFMpegWriter
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Clique of cliques

# %%
graph, pos = generate_clique_of_cliques(seed=0)
        
# initialise the code with parameters and graph 
graph.graph['name'] = 'clique_of_cliques'
graph = assign_graph_metadata(graph, pos=pos)

# initialise the code with parameters and graph
gc = GeoCluster(graph, T=np.logspace(-6., 1., 30))
                 
#Compute the OR curvatures are all the times
gc.compute_OR_curvatures()

#Plot
gc.plot_edge_curvature(filename = 'CoC', density=True, log=True)
gc.plot_graph_snapshots(filename = 'CoC', edge_width=1)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
# Graph: clique_of_cliques
#
# Compute curvature at each markov time
#   3%|▎         | 1/29 [00:00<00:12,  2.27it/s]
#
#
#
#   7%|▋         | 2/29 [00:00<00:11,  2.25it/s]
#
#
#
#  10%|█         | 3/29 [00:01<00:11,  2.27it/s]
#
#
#
#  14%|█▍        | 4/29 [00:01<00:10,  2.28it/s]
#
#
#
#  17%|█▋        | 5/29 [00:02<00:10,  2.26it/s]
#
#
#
#  21%|██        | 6/29 [00:02<00:10,  2.25it/s]
#
#
#
#  24%|██▍       | 7/29 [00:03<00:09,  2.24it/s]
#
#
#
#  28%|██▊       | 8/29 [00:03<00:09,  2.19it/s]
#
#
#
#  31%|███       | 9/29 [00:04<00:09,  2.16it/s]
#
#
#
#  34%|███▍      | 10/29 [00:04<00:08,  2.18it/s]
#
#
#
#  38%|███▊      | 11/29 [00:04<00:08,  2.16it/s]
#
#
#
#  41%|████▏     | 12/29 [00:05<00:07,  2.19it/s]
#
#
#
#  45%|████▍     | 13/29 [00:05<00:07,  2.20it/s]
#
#
#
#  48%|████▊     | 14/29 [00:06<00:06,  2.21it/s]
#
#
#
#  52%|█████▏    | 15/29 [00:06<00:06,  2.22it/s]
#
#
#
#  55%|█████▌    | 16/29 [00:07<00:05,  2.24it/s]
#
#
#
#  59%|█████▊    | 17/29 [00:07<00:05,  2.09it/s]
#
#
#
#  62%|██████▏   | 18/29 [00:08<00:05,  2.01it/s]
#
#
#
#  66%|██████▌   | 19/29 [00:09<00:06,  1.66it/s]
#
#
#
#  69%|██████▉   | 20/29 [00:10<00:06,  1.43it/s]
#
#
#
#  72%|███████▏  | 21/29 [00:11<00:06,  1.25it/s]
#
#
#
#  76%|███████▌  | 22/29 [00:12<00:06,  1.01it/s]
#
#
#
#  79%|███████▉  | 23/29 [00:14<00:08,  1.34s/it]
#
#
#
#  83%|████████▎ | 24/29 [00:18<00:09,  1.94s/it]
#
#
#
#  86%|████████▌ | 25/29 [00:23<00:11,  2.90s/it]
#
#
#
#  90%|████████▉ | 26/29 [00:31<00:13,  4.57s/it]
#
#
#
#  93%|█████████▎| 27/29 [00:45<00:15,  7.50s/it]
#
#
#
#  97%|█████████▋| 28/29 [01:10<00:12, 12.59s/it]
#
#
#
# 100%|██████████| 29/29 [01:52<00:00,  3.88s/it]
#
#
#
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# plot images
#   3%|▎         | 1/29 [00:00<00:08,  3.26it/s]
#
#
#
#   7%|▋         | 2/29 [00:00<00:08,  3.24it/s]
#
#
#
#  10%|█         | 3/29 [00:00<00:08,  3.24it/s]
#
#
#
#  14%|█▍        | 4/29 [00:01<00:07,  3.23it/s]
#
#
#
#  17%|█▋        | 5/29 [00:01<00:07,  3.24it/s]
#
#
#
#  21%|██        | 6/29 [00:01<00:07,  3.24it/s]
#
#
#
#  24%|██▍       | 7/29 [00:02<00:06,  3.21it/s]
#
#
#
#  28%|██▊       | 8/29 [00:02<00:06,  3.21it/s]
#
#
#
#  31%|███       | 9/29 [00:02<00:06,  3.21it/s]
#
#
#
#  34%|███▍      | 10/29 [00:03<00:05,  3.23it/s]
#
#
#
#  38%|███▊      | 11/29 [00:03<00:05,  3.25it/s]
#
#
#
#  41%|████▏     | 12/29 [00:03<00:05,  3.27it/s]
#
#
#
#  45%|████▍     | 13/29 [00:04<00:04,  3.28it/s]
#
#
#
#  48%|████▊     | 14/29 [00:04<00:04,  3.30it/s]
#
#
#
#  52%|█████▏    | 15/29 [00:04<00:04,  3.30it/s]
#
#
#
#  55%|█████▌    | 16/29 [00:05<00:04,  2.82it/s]
#
#
#
#  59%|█████▊    | 17/29 [00:05<00:04,  2.93it/s]
#
#
#
#  62%|██████▏   | 18/29 [00:05<00:03,  2.99it/s]
#
#
#
#  66%|██████▌   | 19/29 [00:06<00:03,  3.05it/s]
#
#
#
#  69%|██████▉   | 20/29 [00:06<00:02,  3.08it/s]
#
#
#
#  72%|███████▏  | 21/29 [00:06<00:02,  3.11it/s]
#
#
#
#  76%|███████▌  | 22/29 [00:06<00:02,  3.14it/s]
#
#
#
#  79%|███████▉  | 23/29 [00:07<00:01,  3.16it/s]
#
#
#
#  83%|████████▎ | 24/29 [00:07<00:01,  3.15it/s]
#
#
#
#  86%|████████▌ | 25/29 [00:07<00:01,  3.18it/s]
#
#
#
#  90%|████████▉ | 26/29 [00:08<00:00,  3.17it/s]
#
#
#
#  93%|█████████▎| 27/29 [00:08<00:00,  3.19it/s]
#
#
#
#  97%|█████████▋| 28/29 [00:08<00:00,  3.18it/s]
#
#
#
# 100%|██████████| 29/29 [00:09<00:00,  3.16it/s]

# %% [markdown]
# # Vary size of barbells

# %%
#Generate graph 
params_1 = [{'m1': i, 'm2': 0} for i in range(3,60,10)]

kappas_1 = {}
for i in range(len(params_1)):
    graph,_ = generate_barbell(params_1[i])
        
    # initialise the code with parameters and graph 
    graph.graph['name'] = 'barbell'
    pos = nx.spring_layout(graph, weight='weight')
    graph = assign_graph_metadata(graph, pos=pos)

    # initialise the code with parameters and graph
    gc = GeoCluster(graph, T=np.logspace(-2., 3., 20), use_spectral_gap = False)
                 
    #Compute the OR curvatures are all the times
    gc.compute_OR_curvatures(save=False)
    kappas_1[i] = gc.Kappa
    #gc.pos = [pos[i] for i in range(len(pos))]

    #Plot
    gc.plot_edge_curvature(filename = 'barbell_' + str(i), log=False)
    gc.plot_graph_snapshots(filename = 'barbell_' + str(i), edge_width=1)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#  53%|█████▎    | 10/19 [00:02<00:02,  3.94it/s]
# All edges have positive curvatures, so stopping the computations
#   5%|▌         | 1/19 [00:00<00:02,  6.66it/s]
# plot images
# 100%|██████████| 19/19 [00:02<00:00,  6.55it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#  84%|████████▍ | 16/19 [00:04<00:00,  3.56it/s]
# All edges have positive curvatures, so stopping the computations
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
# 100%|██████████| 19/19 [00:03<00:00,  4.82it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#  95%|█████████▍| 18/19 [00:06<00:00,  2.83it/s]
# All edges have positive curvatures, so stopping the computations
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
# 100%|██████████| 19/19 [00:06<00:00,  2.95it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
# 100%|██████████| 19/19 [00:10<00:00,  1.81it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
# 100%|██████████| 19/19 [00:09<00:00,  1.93it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
# 100%|██████████| 19/19 [00:16<00:00,  1.15it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
# 100%|██████████| 19/19 [00:14<00:00,  1.31it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
# 100%|██████████| 19/19 [00:30<00:00,  1.58s/it]
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
# 100%|██████████| 19/19 [00:20<00:00,  1.08s/it]

# %%
min_kappa_1 = [kappas_1[i].min() for i in range(len(kappas_1))]
n = [2*params_1[i]['m1'] for i in range(len(kappas_1))]
plt.plot(n, min_kappa_1)
plt.xlabel('Number of nodes')
plt.ylabel(r'$\min \,\kappa_{ij}$')
plt.savefig('vary_m1.svg')
plt.show()

# %% [markdown]
# # Vary number of edges between barbells

# %%
#Generate graph 
params_2 = [{'m1': 100, 'm2': i} for i in range(10)]

kappas_2 = {}
for i in range(len(params_2)):
    graph,_ = generate_barbell(params_2[i])
        
    # initialise the code with parameters and graph 
    graph.graph['name'] = 'barbell'
    pos = nx.spring_layout(graph, weight='weight')
    graph = assign_graph_metadata(graph, pos=pos)

    # initialise the code with parameters and graph
    gc = GeoCluster(graph, T=np.logspace(-2., 3., 20), use_spectral_gap = False)
                 
    #Compute the OR curvatures are all the times
    gc.compute_OR_curvatures(save=False, workers=16)
    kappas_2[i] = gc.Kappa
    
    #Save results for later analysis
    gc.plot_edge_curvature(filename = 'barbell_2_' + str(i), log=False)
    gc.plot_graph_snapshots(filename = 'barbell_2_' + str(i), edge_width=1, node_size=10)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:05<01:42,  5.69s/it]Process ForkPoolWorker-12027:
# Process ForkPoolWorker-12025:
# Process ForkPoolWorker-12024:
# Process ForkPoolWorker-12026:
# Process ForkPoolWorker-12021:
# Process ForkPoolWorker-12017:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-12022:
# Process ForkPoolWorker-12018:
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-12031:
# Traceback (most recent call last):
# Process ForkPoolWorker-12030:
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-12029:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-12020:
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-12028:
# Process ForkPoolWorker-12023:
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
# KeyboardInterrupt
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-12019:
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 38, in K_ij
#     dNxNy = dist[np.ix_(Nx, Ny)]
# Traceback (most recent call last):
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
# Traceback (most recent call last):
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
# Traceback (most recent call last):
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
# KeyboardInterrupt
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
# KeyboardInterrupt
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
# KeyboardInterrupt
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-d701fc2255cf> in <module>
#      15
#      16     #Compute the OR curvatures are all the times
# ---> 17     gc.compute_OR_curvatures(save=False, workers=16)
#      18     kappas_2[i] = gc.Kappa
#      19
#
# ~/Dropbox/github/geometric_clustering/geocluster/geocluster.py in compute_OR_curvatures(self, with_weights, GPU, workers, cutoff, lamb, save)
#      59             if not GPU:
#      60                 with Pool(processes = workers) as p_kappa:
# ---> 61                     self.Kappa[:, it] = p_kappa.map_async(partial(K_ij, mxs, dist, lamb, cutoff,  with_weights, list(self.G.edges())), range(self.e)).get()
#      62             else:
#      63                 for i in range(len(mxs)):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
min_kappa_2 = [kappas_2[i].min() for i in range(len(kappas_2))]
l = [2*params_2[i]['m2'] for i in range(len(kappas_2))]
plt.plot(l, min_kappa_2)
plt.xlabel('Length of bottleneck')
plt.ylabel(r'$\min\, \kappa_{ij}$')
plt.savefig('vary_m2.svg')
plt.show()

# %% [markdown]
# # Vary weight of single edge between barbells

# %%
#Generate graph 
params_3 = np.logspace(-1,2,10)

#kappas_3 = {}
for i in range(len(params_3)):
    graph,_ = generate_barbell({'m1': 120, 'm2': 0})
    A = nx.adjacency_matrix(graph).astype(float)
    A[119,120] = 1/params_3[i]
    A[120,119] = 1/params_3[i]
    graph = nx.from_numpy_matrix(A.todense())
        
    # initialise the code with parameters and graph 
    graph.graph['name'] = 'barbell'
    pos = nx.spring_layout(graph, weight='weight')
    graph = assign_graph_metadata(graph, pos=pos)

    # initialise the code with parameters and graph
    gc = GeoCluster(graph, T=np.logspace(-2., 3., 20), use_spectral_gap = False)
                 
    #Compute the OR curvatures are all the times
    gc.compute_OR_curvatures(save=False, workers=16)
    kappas_3[i] = gc.Kappa
    
    #Save results for later analysis
    gc.plot_edge_curvature(filename = 'barbell_3_' + str(i), log=False)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:17<05:18, 17.67s/it]
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:25<04:12, 14.85s/it]
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:36<03:39, 13.71s/it]
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:55<03:48, 15.27s/it]
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:04<03:03, 13.13s/it]
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:22<03:11, 14.73s/it]
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:32<02:38, 13.19s/it]
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [01:50<02:40, 14.62s/it]
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [02:08<02:36, 15.69s/it]
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:21<02:14, 15.00s/it]
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [02:39<02:06, 15.81s/it]
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [02:54<01:49, 15.71s/it]
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:12<01:38, 16.41s/it]
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:29<01:22, 16.55s/it]
# All edges have positive curvatures, so stopping the computations
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:05<01:36,  5.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:10<01:28,  5.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:15<01:21,  5.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:20<01:17,  5.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:25<01:11,  5.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:30<01:05,  5.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:35<01:01,  5.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:40<00:55,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:45<00:50,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:50<00:44,  4.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:55<00:40,  5.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [01:00<00:35,  5.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:05<00:29,  4.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:10<00:25,  5.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:15<00:20,  5.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:20<00:15,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:25<00:09,  4.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:30<00:05,  5.10s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:35<00:00,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:09<02:55,  9.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:22<03:03, 10.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:31<02:42, 10.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:50<03:09, 12.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:06<03:13, 13.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:23<03:12, 14.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:41<03:09, 15.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [02:00<03:03, 16.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [02:18<02:50, 17.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:34<02:29, 16.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [02:50<02:12, 16.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [03:04<01:51, 15.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:18<01:31, 15.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:33<01:15, 15.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [03:48<01:00, 15.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [03:55<00:37, 12.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [04:02<00:21, 10.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [04:10<00:10, 10.05s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [04:19<00:00, 13.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:05<01:31,  5.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:10<01:29,  5.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:15<01:22,  5.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:20<01:16,  5.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:25<01:11,  5.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:30<01:05,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:35<01:00,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:40<00:55,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:46<00:53,  5.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:51<00:46,  5.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:56<00:41,  5.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [01:01<00:35,  5.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:06<00:30,  5.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:11<00:25,  5.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:16<00:20,  5.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:22<00:15,  5.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:27<00:10,  5.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:32<00:05,  5.19s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:37<00:00,  5.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:18<05:39, 18.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:37<05:17, 18.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:48<04:22, 16.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [01:06<04:14, 16.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:25<04:04, 17.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:35<03:20, 15.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:45<02:43, 13.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [01:55<02:17, 12.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [02:11<02:15, 13.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:26<02:06, 14.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [02:42<01:58, 14.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [02:56<01:41, 14.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:11<01:28, 14.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:28<01:16, 15.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [03:45<01:03, 15.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [03:52<00:39, 13.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [03:59<00:22, 11.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [04:07<00:10, 10.26s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [04:16<00:00, 13.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:05<01:33,  5.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:11<01:33,  5.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:16<01:26,  5.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:21<01:19,  5.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:26<01:12,  5.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:31<01:07,  5.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:36<01:01,  5.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:41<00:56,  5.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:47<00:51,  5.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:52<00:46,  5.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:57<00:40,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [01:03<00:38,  5.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:08<00:31,  5.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:13<00:26,  5.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:18<00:20,  5.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:23<00:15,  5.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:28<00:10,  5.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:33<00:05,  5.06s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:38<00:00,  5.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:08<02:31,  8.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:20<02:39,  9.38s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:38<03:13, 12.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:55<03:25, 13.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:07<03:03, 13.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:18<02:43, 12.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:30<02:28, 12.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [01:48<02:33, 13.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [01:59<02:10, 13.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:15<02:07, 14.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [02:33<02:00, 15.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [02:50<01:49, 15.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:06<01:35, 15.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:20<01:16, 15.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [03:32<00:56, 14.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [03:39<00:36, 12.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [03:46<00:21, 10.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [03:54<00:09,  9.84s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [04:03<00:00, 12.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:05<01:30,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:09<01:25,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:15<01:20,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:21<01:22,  5.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:26<01:14,  5.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:31<01:07,  5.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:36<01:01,  5.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:41<00:55,  5.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:46<00:50,  5.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:51<00:45,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:56<00:39,  4.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [01:01<00:34,  4.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:06<00:29,  4.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:11<00:24,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:16<00:19,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:20<00:14,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:25<00:09,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:32<00:05,  5.43s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:37<00:00,  5.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:09<02:51,  9.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:22<02:58, 10.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:34<02:56, 11.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:51<03:10, 12.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:05<03:06, 13.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:23<03:09, 14.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:32<02:33, 12.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [01:43<02:14, 12.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [02:00<02:18, 13.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:16<02:09, 14.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [02:32<01:59, 14.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [02:49<01:48, 15.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:02<01:28, 14.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:17<01:14, 14.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [03:34<01:01, 15.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [03:41<00:38, 12.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [03:48<00:22, 11.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [03:56<00:10, 10.31s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [04:06<00:00, 12.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:05<01:30,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:12<01:35,  5.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:17<01:26,  5.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:21<01:19,  5.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:26<01:12,  5.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:31<01:06,  5.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:36<01:00,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:41<00:55,  5.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:46<00:50,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:51<00:44,  4.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:56<00:39,  4.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [01:01<00:34,  4.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:06<00:29,  4.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:11<00:24,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:16<00:19,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:21<00:14,  4.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:26<00:09,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:31<00:04,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:38<00:00,  5.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:16<04:51, 16.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:34<04:45, 16.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:53<04:39, 17.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [01:10<04:20, 17.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:19<03:28, 14.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:37<03:25, 15.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:50<03:00, 15.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [02:08<02:52, 15.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [02:20<02:27, 14.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:38<02:22, 15.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [02:53<02:04, 15.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [03:08<01:46, 15.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:23<01:31, 15.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:40<01:18, 15.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [03:57<01:05, 16.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [04:04<00:40, 13.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [04:12<00:23, 11.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [04:20<00:10, 10.65s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [04:30<00:00, 14.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:04<01:27,  4.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:09<01:23,  4.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:14<01:18,  4.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:19<01:13,  4.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:24<01:08,  4.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:29<01:03,  4.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:36<01:07,  5.61s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:41<00:59,  5.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:46<00:52,  5.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:51<00:46,  5.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:56<00:40,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [01:00<00:34,  4.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:05<00:29,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:10<00:24,  4.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:15<00:19,  4.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:20<00:14,  4.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:25<00:09,  4.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:30<00:04,  4.87s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:34<00:00,  5.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:17<05:22, 17.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:27<04:23, 15.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:46<04:23, 16.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [01:04<04:14, 16.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:14<03:28, 14.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:31<03:19, 15.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:49<03:16, 16.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [02:08<03:08, 17.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [02:27<02:55, 17.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:44<02:36, 17.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [03:00<02:17, 17.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [03:17<01:59, 17.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:33<01:40, 16.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:48<01:21, 16.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [04:05<01:05, 16.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [04:12<00:40, 13.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [04:20<00:23, 11.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [04:28<00:10, 10.76s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [04:38<00:00, 14.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:05<01:31,  5.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:10<01:26,  5.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:15<01:21,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:20<01:16,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:25<01:10,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:30<01:05,  5.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:35<01:00,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:40<00:55,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:45<00:50,  5.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:50<00:45,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:55<00:40,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [01:00<00:35,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:05<00:30,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:10<00:25,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:15<00:20,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:20<00:15,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:25<00:10,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:30<00:05,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:35<00:00,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:17<05:23, 18.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:26<04:19, 15.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:45<04:21, 16.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [01:03<04:10, 16.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:21<03:58, 17.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:39<03:46, 17.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:56<03:27, 17.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [02:08<02:51, 15.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [02:22<02:33, 15.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:39<02:21, 15.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [02:54<02:04, 15.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [03:10<01:50, 15.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:28<01:37, 16.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:45<01:22, 16.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [04:02<01:06, 16.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [04:09<00:41, 13.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [04:17<00:23, 11.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [04:25<00:10, 10.86s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [04:35<00:00, 14.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:05<01:30,  5.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:10<01:25,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:15<01:20,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:20<01:15,  5.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:25<01:10,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:30<01:05,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:35<01:00,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:40<00:55,  5.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:45<00:50,  5.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:50<00:45,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:55<00:40,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [01:00<00:35,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:05<00:29,  5.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:10<00:24,  4.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:15<00:19,  4.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:19<00:14,  4.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:28<00:11,  5.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:32<00:05,  5.61s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:37<00:00,  5.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:09<02:53,  9.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:18<02:38,  9.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:36<03:10, 11.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:54<03:27, 13.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:12<03:32, 15.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:22<02:54, 13.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:32<02:29, 12.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [01:43<02:13, 12.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [01:56<02:03, 12.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:12<02:01, 13.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [02:29<01:56, 14.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [02:45<01:43, 14.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:02<01:32, 15.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:15<01:13, 14.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [03:28<00:57, 14.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [03:36<00:37, 12.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [03:45<00:22, 11.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [03:53<00:10, 10.41s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [04:03<00:00, 12.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:05<01:31,  5.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:10<01:25,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:15<01:20,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:19<01:14,  4.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:24<01:09,  4.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:29<01:04,  4.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:34<00:59,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:39<00:54,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:44<00:49,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:49<00:44,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:54<00:39,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [00:59<00:34,  4.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:04<00:29,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:09<00:24,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:14<00:19,  4.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:22<00:18,  6.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:27<00:11,  5.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:32<00:05,  5.49s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:37<00:00,  5.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: barbell
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:09<02:57,  9.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:27<03:27, 12.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:38<03:11, 11.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:54<03:17, 13.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [01:07<03:00, 12.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [01:25<03:07, 14.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [01:42<03:04, 15.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [01:52<02:30, 13.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [02:08<02:25, 14.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [02:24<02:14, 14.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [02:40<02:01, 15.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [02:58<01:51, 15.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [03:15<01:37, 16.19s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [03:30<01:19, 15.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [03:48<01:05, 16.44s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [03:55<00:41, 13.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [04:03<00:23, 12.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [04:12<00:10, 10.98s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [04:21<00:00, 13.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:05<01:31,  5.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#  11%|█         | 2/19 [00:10<01:25,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  16%|█▌        | 3/19 [00:15<01:22,  5.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#  21%|██        | 4/19 [00:20<01:17,  5.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#  26%|██▋       | 5/19 [00:25<01:11,  5.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 6/19 [00:30<01:05,  5.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#  37%|███▋      | 7/19 [00:35<01:01,  5.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#  42%|████▏     | 8/19 [00:40<00:55,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  47%|████▋     | 9/19 [00:45<00:50,  5.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#  53%|█████▎    | 10/19 [00:50<00:45,  5.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#  58%|█████▊    | 11/19 [00:55<00:40,  5.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 12/19 [01:00<00:35,  5.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#  68%|██████▊   | 13/19 [01:05<00:29,  5.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#  74%|███████▎  | 14/19 [01:10<00:24,  5.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#  79%|███████▉  | 15/19 [01:15<00:19,  4.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 16/19 [01:20<00:14,  4.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#  89%|████████▉ | 17/19 [01:29<00:12,  6.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#  95%|█████████▍| 18/19 [01:34<00:05,  5.87s/it]
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 19/19 [01:39<00:00,  5.26s/it]

# %%
min_kappa_3 = [kappas_3[i].min() for i in range(len(kappas_3))]
w = [params_3[i] for i in range(len(kappas_3))]
plt.plot(w, min_kappa_3)
plt.xlabel('Weight of bottleneck')
plt.ylabel(r'$\min\, \kappa_{ij}$')
plt.savefig('vary_w.svg')
plt.show()

# %% [markdown]
# # Vary height of tree

# %%
#Generate graph 
params_1 = [{'r': 2, 'h': i} for i in range(2,7)]

kappas_1 = {}
for i in range(len(params_1)):
    graph,_ = generate_tree(params_1[i])
        
    # initialise the code with parameters and graph 
    graph.graph['name'] = 'tree'
    pos = nx.spring_layout(graph, weight='weight')
    graph = assign_graph_metadata(graph, pos=pos)

    # initialise the code with parameters and graph
    gc = GeoCluster(graph, T=np.logspace(-2., 3., 20), use_spectral_gap = False)
                 
    #Compute the OR curvatures are all the times
    gc.compute_OR_curvatures(save=False)
    kappas_1[i] = gc.Kappa
    gc.pos = [pos[i] for i in range(len(pos))]

    #Save results for later analysis
    gc.plot_edge_curvature(filename = 'tree_1_' + str(i), log=False)
    gc.plot_graph_snapshots(filename = 'tree_1_' + str(i), edge_width=1, node_size=10)

# %% [markdown]
# # Vary branching factor of tree

# %%
#Generate graph 
params_2 = [{'r': i, 'h': 5} for i in range(2,7)]

kappas_2 = {}
for i in range(len(params_2)):
    graph,_ = generate_tree(params_2[i])
        
    # initialise the code with parameters and graph 
    graph.graph['name'] = 'tree'
    pos = nx.spring_layout(graph, weight='weight')
    graph = assign_graph_metadata(graph, pos=pos)

    # initialise the code with parameters and graph
    gc = GeoCluster(graph, T=np.logspace(-2., 3., 20), use_spectral_gap = False)
                 
    #Compute the OR curvatures are all the times
    gc.compute_OR_curvatures(save=False)
    kappas_2[i] = gc.Kappa
    gc.pos = [pos[i] for i in range(len(pos))]

    #Save results for later analysis
    gc.plot_edge_curvature(filename = 'tree_2_' + str(i), log=False)
    gc.plot_graph_snapshots(filename = 'tree_2_' + str(i), edge_width=1, node_size=10)
