# %%
import numpy as np
import sys as sys
import os as os
from geocluster import GeoCluster
from graph_library import generate_tree, assign_graph_metadata
import networkx as nx
import scipy as sc
import pylab as plt
import matplotlib.gridspec as gridspec
from matplotlib.animation import FFMpegWriter
from IPython.display import display

# %% [markdown]
# # Vary height of tree

# %%
#Generate graph 
params_1 = [{'r': 2, 'h': i} for i in range(2,7)]

kappas_1 = {}
for i in range(len(params_1)):
    graph,_ = generate_tree(params_1[i])
        
    # initialise the code with parameters and graph 
    graph.graph['name'] = 'tree'
    pos = nx.spring_layout(graph, weight='weight')
    graph = assign_graph_metadata(graph, pos=pos)

    # initialise the code with parameters and graph
    gc = GeoCluster(graph, T=np.logspace(-2., 3., 20), use_spectral_gap = False)
                 
    #Compute the OR curvatures are all the times
    gc.compute_OR_curvatures(save=False)
    kappas_1[i] = gc.Kappa
    gc.pos = [pos[i] for i in range(len(pos))]

    #Save results for later analysis
    gc.plot_edge_curvature(filename = 'tree_1_' + str(i), log=False)
    gc.plot_graph_snapshots(filename = 'tree_1_' + str(i), edge_width=1, node_size=10)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: tree
#
# Compute curvature at each markov time
#  47%|████▋     | 9/19 [00:02<00:02,  3.88it/s]
# All edges have positive curvatures, so stopping the computations
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
# 100%|██████████| 19/19 [00:05<00:00,  3.21it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: tree
#
# Compute curvature at each markov time
#  63%|██████▎   | 12/19 [00:03<00:01,  3.96it/s]
# All edges have positive curvatures, so stopping the computations
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
# 100%|██████████| 19/19 [00:06<00:00,  3.12it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: tree
#
# Compute curvature at each markov time
#  74%|███████▎  | 14/19 [00:03<00:01,  3.53it/s]
# All edges have positive curvatures, so stopping the computations
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
# 100%|██████████| 19/19 [00:04<00:00,  3.83it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: tree
#
# Compute curvature at each markov time
#  84%|████████▍ | 16/19 [00:07<00:01,  2.12it/s]
# All edges have positive curvatures, so stopping the computations
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
# 100%|██████████| 19/19 [00:05<00:00,  3.75it/s]
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: tree
#
# Compute curvature at each markov time
#  89%|████████▉ | 17/19 [00:10<00:02,  1.08s/it]
# All edges have positive curvatures, so stopping the computations
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:00<00:07,  2.36it/s]
#  11%|█         | 2/19 [00:00<00:07,  2.36it/s]
#  16%|█▌        | 3/19 [00:01<00:06,  2.38it/s]
#  21%|██        | 4/19 [00:01<00:06,  2.38it/s]
#  26%|██▋       | 5/19 [00:02<00:05,  2.38it/s]
#  32%|███▏      | 6/19 [00:02<00:05,  2.35it/s]
#  37%|███▋      | 7/19 [00:02<00:05,  2.35it/s]
#  42%|████▏     | 8/19 [00:03<00:04,  2.33it/s]
#  47%|████▋     | 9/19 [00:03<00:04,  2.34it/s]
#  53%|█████▎    | 10/19 [00:04<00:03,  2.35it/s]
#  58%|█████▊    | 11/19 [00:04<00:03,  2.36it/s]
#  63%|██████▎   | 12/19 [00:05<00:02,  2.36it/s]
#  68%|██████▊   | 13/19 [00:05<00:02,  2.05it/s]
#  74%|███████▎  | 14/19 [00:06<00:02,  2.14it/s]
#  79%|███████▉  | 15/19 [00:06<00:01,  2.21it/s]
#  84%|████████▍ | 16/19 [00:06<00:01,  2.27it/s]
#  89%|████████▉ | 17/19 [00:07<00:00,  2.51it/s]
#  95%|█████████▍| 18/19 [00:07<00:00,  2.72it/s]
# 100%|██████████| 19/19 [00:07<00:00,  2.40it/s]

# %% [markdown]
# # Vary degree of nodes

# %%
#Generate graph 
params_2 = [{'r': i, 'h': 5} for i in range(2,7)]

kappas_2 = {}
for i in range(len(params_2)):
    graph,_ = generate_tree(params_2[i])
        
    # initialise the code with parameters and graph 
    graph.graph['name'] = 'tree'
    pos = nx.spring_layout(graph, weight='weight')
    graph = assign_graph_metadata(graph, pos=pos)

    # initialise the code with parameters and graph
    gc = GeoCluster(graph, T=np.logspace(-2., 3., 20), use_spectral_gap = False)
                 
    #Compute the OR curvatures are all the times
    gc.compute_OR_curvatures(save=False)
    kappas_2[i] = gc.Kappa
    gc.pos = [pos[i] for i in range(len(pos))]

    #Save results for later analysis
    gc.plot_edge_curvature(filename = 'tree_2_' + str(i), log=False)
    gc.plot_graph_snapshots(filename = 'tree_2_' + str(i), edge_width=1, node_size=10)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# Graph: tree
#
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:00<00:04,  4.20it/s]
#
#  11%|█         | 2/19 [00:00<00:04,  4.14it/s]
#
#  16%|█▌        | 3/19 [00:00<00:04,  3.99it/s]
#
#  21%|██        | 4/19 [00:01<00:03,  4.02it/s]
#
#  26%|██▋       | 5/19 [00:01<00:03,  4.08it/s]
#
#  32%|███▏      | 6/19 [00:01<00:03,  4.05it/s]
#
#  37%|███▋      | 7/19 [00:01<00:02,  4.10it/s]
#
#  42%|████▏     | 8/19 [00:01<00:02,  4.15it/s]
#
#  47%|████▋     | 9/19 [00:02<00:02,  4.19it/s]
#
#  53%|█████▎    | 10/19 [00:02<00:02,  4.23it/s]
#
#  58%|█████▊    | 11/19 [00:02<00:01,  4.27it/s]
#
#  63%|██████▎   | 12/19 [00:02<00:01,  4.13it/s]
#
#  68%|██████▊   | 13/19 [00:03<00:01,  3.68it/s]
#
#  74%|███████▎  | 14/19 [00:03<00:01,  3.42it/s]
#
#  79%|███████▉  | 15/19 [00:04<00:01,  2.99it/s]
#
#  84%|████████▍ | 16/19 [00:04<00:01,  2.07it/s]
#
#  89%|████████▉ | 17/19 [00:06<00:01,  1.47it/s]
# All edges have positive curvatures, so stopping the computations
#   0%|          | 0/19 [00:00<?, ?it/s]
# plot images
#   5%|▌         | 1/19 [00:00<00:03,  4.86it/s]
#
#
#  11%|█         | 2/19 [00:00<00:03,  4.85it/s]
#
#
#  16%|█▌        | 3/19 [00:00<00:03,  4.85it/s]
#
#
#  21%|██        | 4/19 [00:00<00:03,  4.86it/s]
#
#
#  26%|██▋       | 5/19 [00:01<00:02,  4.88it/s]
#
#
#  32%|███▏      | 6/19 [00:01<00:02,  4.68it/s]
#
#
#  37%|███▋      | 7/19 [00:01<00:02,  4.74it/s]
#
#
#  42%|████▏     | 8/19 [00:01<00:02,  4.77it/s]
#
#
#  47%|████▋     | 9/19 [00:01<00:02,  4.81it/s]
#
#
#  53%|█████▎    | 10/19 [00:02<00:01,  4.81it/s]
#
#
#  58%|█████▊    | 11/19 [00:02<00:01,  4.83it/s]
#
#
#  63%|██████▎   | 12/19 [00:02<00:01,  4.87it/s]
#
#
#  68%|██████▊   | 13/19 [00:02<00:01,  4.89it/s]
#
#
#  74%|███████▎  | 14/19 [00:02<00:01,  4.91it/s]
#
#
#  79%|███████▉  | 15/19 [00:03<00:00,  4.68it/s]
#
#
#  84%|████████▍ | 16/19 [00:03<00:00,  4.76it/s]
#
#
#  89%|████████▉ | 17/19 [00:03<00:00,  4.77it/s]
#
#
#  95%|█████████▍| 18/19 [00:03<00:00,  4.83it/s]
#
#
# 100%|██████████| 19/19 [00:03<00:00,  4.81it/s]
# Graph: tree
#   0%|          | 0/19 [00:00<?, ?it/s]
# Compute curvature at each markov time
#   5%|▌         | 1/19 [00:02<00:53,  2.95s/it]
#
#
#  11%|█         | 2/19 [00:06<00:53,  3.13s/it]
#
#
#  16%|█▌        | 3/19 [00:11<00:59,  3.71s/it]
#
#
#  21%|██        | 4/19 [00:20<01:17,  5.14s/it]
#
#
#  26%|██▋       | 5/19 [00:37<02:03,  8.81s/it]Process ForkPoolWorker-472:
# Process ForkPoolWorker-471:
# Traceback (most recent call last):
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 38, in K_ij
#     dNxNy = dist[np.ix_(Nx, Ny)]
#   File "/home/gosztolai/anaconda3/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
# KeyboardInterrupt
#   File "/home/gosztolai/Dropbox/github/geometric_clustering/geocluster/curvature.py", line 51, in K_ij
#     W = ot.emd2(mx, my, dNxNy)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 234, in emd2
#     return f(b)
#   File "/home/gosztolai/anaconda3/lib/python3.7/site-packages/ot/lp/__init__.py", line 229, in f
#     G, cost, u, v, result_code = emd_c(a, b, M, numItermax)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e3eaf190dd3e> in <module>
#      15
#      16     #Compute the OR curvatures are all the times
# ---> 17     gc.compute_OR_curvatures(save=False)
#      18     kappas_2[i] = gc.Kappa
#      19     gc.pos = [pos[i] for i in range(len(pos))]
#
# ~/Dropbox/github/geometric_clustering/geocluster/geocluster.py in compute_OR_curvatures(self, with_weights, GPU, workers, cutoff, lamb, save)
#      59             if not GPU:
#      60                 with Pool(processes = workers) as p_kappa:
# ---> 61                     self.Kappa[:, it] = p_kappa.map_async(partial(K_ij, mxs, dist, lamb, cutoff,  with_weights, list(self.G.edges())), range(self.e)).get()
#      62             else:
#      63                 for i in range(len(mxs)):
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
